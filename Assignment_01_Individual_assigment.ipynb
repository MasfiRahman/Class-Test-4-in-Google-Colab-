# %% [markdown]
# ### **Assignment 01: Individual Assignment**
#
# **Marks**: 10
# **Total Contribution**: 10% in assessment
#
#
# ---
#
# ### **Rules and Submission Guideline**:
#
# * Create a `.ipynb` file with your **student ID** and **personal information such as, full name, sectoin** included.
# * Submit your solution by the deadline: **Last date of PL, 11:59:59 PM**
# * If any part of the code appears to be AI-generated, **zero** mark will be given, you can challenge the mark; to defend you will have to face a **viva**. Up to **three questions** can be asked and 3 marks will be deducted upon failing to answer each quesetion. Failure to correctly answer **all questions** will result in **zero marks**.
#
# ---

# %% [markdown]
# ---
#
# ## 🚩 Problem Statement: **Virtual Smart City Simulator**
#
# You are tasked with designing a **Virtual Smart City Simulator** that tracks **citizens**, **buildings**, and **energy consumption** in a city.
# Your system should simulate **daily life** where people **move into buildings**, **consume energy**, and **generate reports**.
#
# ---
#
# ## ✅ Requirements
#
# ### **Classes**
#
# ---
#
# ### 🔹 `Citizen` (**3 Marks**)
#
# Represents a person living in the city.
#
# **Attributes**:
#
# * `name`: Name of the citizen
# * `energy_used`: Total amount of energy used (in kWh)
#
# **Methods**:
#
# * `use_energy(amount)`: Adds the given amount to the citizen’s energy usage
# * `__str__`: Returns `"Citizen Name - Energy Used: X kWh"`
#
# ---
#
# ### 🔹 `Building` (**4 Marks**)
#
# Represents a residential building that holds multiple citizens.
#
# **Attributes**:
#
# * `building_name`: Name of the building
# * `citizens`: List of `Citizen` objects living there
# * `total_energy`: Total building energy usage
#
# **Methods**:
#
# * `add_citizen(citizen)`: Adds a citizen to the building
# * `calculate_energy()`: Updates `total_energy` by summing all citizens’ energy usage
# * `__str__()`: Returns summary →
#   `"Building <name> | Total Energy: X kWh | Residents: <list of names>"`
#
# ---
#
# ### 🔹 `City` (**6 Marks**)
#
# Represents the overall smart city.
#
# **Attributes**:
#
# * `city_name`: Name of the city
# * `buildings`: List of `Building` objects
# * `city_energy`: Total city energy usage
#
# **Methods**:
#
# * `add_building(building)`: Adds a building to the city
# * `simulate_day()`: Randomly assigns energy usage to each citizen (between 1–10 kWh)
# * `generate_report()`: Displays:
#
#   * Total city energy
#   * Energy usage per building
#   * Top 3 highest energy-consuming citizens
#
# ---
#
#
# ## 🧩 **Sample Input:**
#
# *(This is not literal input typed by the user — it represents what happens in the program execution.)*
#
# ```python
# # Create city and buildings
# city = City("NeoDhaka")
#
# b1 = Building("Skyline Tower")
# b2 = Building("RiverView Heights")
#
# city.add_building(b1)
# city.add_building(b2)
#
# # Add citizens
# b1.add_citizen(Citizen("Mahmud"))
# b1.add_citizen(Citizen("Anika"))
# b2.add_citizen(Citizen("Farhan"))
# b2.add_citizen(Citizen("Rafi"))
# b2.add_citizen(Citizen("Tania"))
#
# # Simulate and report
# city.simulate_day()
# city.generate_report()
# ```
#
# ---
#
# ## 🧾 **Sample Output (Randomized Example):**
#
# ```
# 🌇 Simulating a day in NeoDhaka...
#
# 🔌 Mahmud used 8 kWh in Skyline Tower
# 🔌 Anika used 3 kWh in Skyline Tower
# 🔌 Farhan used 9 kWh in RiverView Heights
# 🔌 Rafi used 5 kWh in RiverView Heights
# 🔌 Tania used 2 kWh in RiverView Heights
#
# 📊 Energy Report for NeoDhaka
# =============================================
# 🏙️ Total City Energy Used: 27 kWh
#
# 🏢 Skyline Tower | Total Energy: 11 kWh | Residents: Mahmud, Anika
# 🏢 RiverView Heights | Total Energy: 16 kWh | Residents: Farhan, Rafi, Tania
#
# 🔥 Top 3 Energy Consumers:
#    Farhan → 9 kWh
#    Mahmud → 8 kWh
#    Rafi → 5 kWh
# =============================================
# ```
#
# ---
